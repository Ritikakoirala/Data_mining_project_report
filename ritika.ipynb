# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
df=pd.read_csv('data.csv')
df.head(10)
# Out:
#    Invoice_ID   Age  Gender Product_Category  Unit_Price  Quantity  \
# 0        1001  25.0    Male      Electronics       500.0       1.0
# 1        1002  30.0  Female         Clothing        50.0       2.0
# 2        1003  22.0     NaN        Groceries        20.0       5.0
# 3        1004  28.0    Male      Electronics         NaN       1.0
# 4        1005  35.0  Female         Clothing        60.0       NaN
# 5        1006  40.0    Male        Groceries        15.0      10.0
# 6        1007  29.0  Female      Electronics       700.0       1.0
# 7        1008  31.0    Male         Clothing        80.0       2.0
# 8        1009   NaN  Female        Groceries        25.0       4.0
# 9        1010  45.0    Male      Electronics      1000.0       1.0
#
#    Total_Amount       City
# 0           500  Kathmandu
# 1           100    Pokhara
# 2           100   Lalitpur
# 3           500  Kathmandu
# 4           120        NaN
# 5           150  Bhaktapur
# 6           700  Kathmandu
# 7           160    Pokhara
# 8           100   Lalitpur
# 9          1000  Kathmandu

# %%
df.dtypes
# Out:
# Invoice_ID            int64
# Age                 float64
# Gender               object
# Product_Category     object
# Unit_Price          float64
# Quantity            float64
# Total_Amount          int64
# City                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Invoice_ID          0
# Age                 1
# Gender              1
# Product_Category    0
# Unit_Price          1
# Quantity            1
# Total_Amount        0
# City                1
# dtype: int64
